# %% [markdown]
# # Análisis de contratación

# %% [markdown]
# Instalar los complementos para el análisis de la información

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import matplotlib.path as path
# %matplotlib inline

# %% [markdown]
# # Cargar los datos desde excel

# %%
# Importar la base de datos 
excel_file = 'base excel.xlsx'
base = pd.read_excel(excel_file)

# %%
base
# Out:
#                  Código Contrato  \
# 0                         F90018
# 1                         F90019
# 2                         F90020
# 3                         F90021
# 4                         F90022
# 5                         F90023
# 6                         F90024
# 7                         F90025
# 8                         F90026
# 9                         F90027
# 10                        F90028
# 11                        F90030
# 12                        F90031
# 13                        F90032
# 14                        F90033
# 15                        F90034
# 16                        F90035
# 17                        F90038
# 18                        F90039
# 19                        F90040
# 20                  OAG-VEX-0290
# 21                 OPSP-VEX-0234
# 22                     1044-2019
# 23                      134-2019
# 24                      946-2019
# 25                    AR013-2019
# 26                B-OCS-001-2019
# 27     B-OCS-001SUMINISTROS-2019
# 28                B-OPS-001-2019
# 29                B-OPS-002-2019
# ...                          ...
# 39400                   291-2019
# 39401                   292-2019
# 39402                   293-2019
# 39403                   294-2019
# 39404                   295-2019
# 39405                   298-2019
# 39406                   299-2019
# 39407                   300-2019
# 39408                   301-2019
# 39409                   303-2019
# 39410                   304-2019
# 39411                   305-2019
# 39412                   306-2019
# 39413                   307-2019
# 39414                   308-2019
# 39415                   309-2019
# 39416                   310-2019
# 39417                   311-2019
# 39418                   312-2019
# 39419                   313-2019
# 39420                   488-2018
# 39421                CM-001-2019
# 39422                CM-002-2019
# 39423                CM-003-2019
# 39424                CM-004-2019
# 39425                CM-005-2019
# 39426                CM-006-2019
# 39427                CM-007-2019
# 39428                CM-008-2019
# 39429                CM-009-2019
#
#                                                   Objeto  \
# 0      SERVICIOS PROFESIONALES PSICOLOGO CON ESPECIAL...
# 1      SERVICIOS PROFESIONALES PSICOLOGA CON EXPERIEN...
# 2      SERVICIOS PROFESIONALES ADMINISTRADOR AMBIENTA...
# 3      SERVICIOS PROFESIONALES PSICOLOGA CON EXPERIEN...
# 4      SERVICIOS PROFESIONALES PSICOLOGO CON EXPERIEN...
# 5      SERVICIOS PROFESIONALES ADMINISTRADOR AMBIENTA...
# 6      SERVICIOS PROFESIONALES PSICOLOGA CON EXPERIEN...
# 7      SERVICIOS PROFESIONALES CONTADOR PUBLICO COMO ...
# 8      SERVIC ESTUD ADMINISTRAC AMBIENTAL, EXPERIENC ...
# 9      SERVICIOS ESTUDIANTE DE INGENIERIA INDUSTRIAL ...
# 10     SERVICIOS PROFESIONALES PSICOLOGA PARA PARA DE...
# 11     SERVICIOS PROFESIONALES REALIZANDO LAS SIGUIEN...
# 12     SERVICIOS PROFES EN DERECHO, PARA DESARROLLAR ...
# 13     SERVICIOS PROFESIONALES ADMINISTRADORA AMBIENT...
# 14     SERVICIOS TECNOLOGA EN FINANZAS Y NEGOCIOS INT...
# 15     SERVICIOS PROFESIONALES PSICOLOGA, REALIZANDO ...
# 16     SERVICIOS PROFESIONALES INGENIERO DE SISTEMAS,...
# 17     SERVICIOS PROFESIONAL EN DERECHO PARA REALIZAR...
# 18     SERVICIOS PROFESIONALES DE UN PSICOLOGO PARA R...
# 19     SERVICIOS DE APLICACION LP 007 PROCESO DE SELE...
# 20     RECOLECTAR LAS ESTADISTICAS PESQUERAS RELATIVA...
# 21     RECOLECTAR, DE ACUERDO AL MECANISMO DE REGISTR...
# 22     PRESTAR COMO CONTRATISTA SUS SERVICIOS PROFESI...
# 23     PRESTAR COMO CONTRATISTA SUS SERVICIOS PERSONA...
# 24     PRESTAR COMO CONTRATISTA SUS SERVICIOS PROFESI...
# 25     EL ARRENDADOR ENTREGA PARA SU USO Y GOCE AL AR...
# 26     EL CONTRATISTA SE COMPROMETE A PRESTAR SUS SER...
# 27     EL CONTRATISTA SE COMPROMETE A SUMINISTRAR ELE...
# 28     EL CONTRATISTA SE COMPROMETE A PRESTAR SUS SER...
# 29     EL CONTRATISTA SE COMPROMETE A REALIZAR ASESOR...
# ...                                                  ...
# 39400  PRESTACION DE SERVICIOS PROFESIONALES PARA EL ...
# 39401  PRESTACION DE SERVICIOS PROFESIONALES PARA EL ...
# 39402  PRESTACION DE SERVICIOS PROFESIONALES PARA ASE...
# 39403  PRESTACION DE SERVICIOS DE APOYO A LA GESTION ...
# 39404  ALQUILER DE ELEMENTOS Y APOYO LOGISTICO PARA E...
# 39405  PRESTACION DE SERVICIOS PROFESIONALES DE TRABA...
# 39406  PRESTACION DE SERVICIOS DE APOYO A LA GESTION ...
# 39407  PRESTACION DE SERVICIOS DE APOYO A LA GESTION ...
# 39408  PRESTACION DE SERVICIOS DE SOPORTE TECNICO, AS...
# 39409  COMPRA DE TINTAS Y TONNERS PARA LAS IMPRESORAS...
# 39410  MEJORAMIENTO DE VIAS TERCIARIAS MEDIANTE EL US...
# 39411  INTERVENTORIA TECNICA, ADMINISTRATIVA Y FINANC...
# 39412  PRESTACION DE SERVICIOS DE APOYO A LA GESTION ...
# 39413  PRESTACION DE SERVICIOS PARA BRINDAR ALBERGUE ...
# 39414  COMPRA DE ELEMENTOS DE PAPELERIA Y ELEMENTOS D...
# 39415  SUMINISTRO DE RACIONES ALIMENTICIAS PARA EL PE...
# 39416  PRESTACION DE SERVICIOS DE APOYO A LA GESTION ...
# 39417  PRESTACION DE SERVICIOS DE ALOJAMIENTO PARA LA...
# 39418  COMPRA DE ELEMENTOS DE ASEO Y CAFETERIA PARA L...
# 39419  PRESTACION DE SERVICIOS PARA LA CELEBRACION DE...
# 39420  INTERVENTORIA TECNICA, ADMINISTRATIVA Y FINANC...
# 39421  PRESTACION DE SERVICIOS PROFESIONALES DE ASESO...
# 39422  PRESTACION DE SERVICIOS PARA LA CLASIFICACION ...
# 39423  PRESTACION DE SERVICIOS DE APOYO A LA GESTION ...
# 39424  PRESTACION DE SERVICIOS DE APOYO A LA GESTION ...
# 39425  PRESTACION DE SERVICIOS PROFESIONALES Y DE APO...
# 39426  PRESTACION DE SERVICIOS Y DE APOYO A LA GESTIO...
# 39427  PRESTACION DE SERVICIOS Y DE APOYO A LA GESTIO...
# 39428  CONTRATAR UNA POLIZA DE SEGUROS DE VIDA GRUPO ...
# 39429  PRESTACION DE SERVICIOS PARA LA PUBLICACION EN...
#
#                            Entidad  Contratante  Valor Inicial  \
# 0      UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       22260000
# 1      UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       14000000
# 2      UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       18900000
# 3      UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       18900000
# 4      UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       22260000
# 5      UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       18900000
# 6      UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       23100000
# 7      UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       11340000
# 8      UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       14700000
# 9      UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       14700000
# 10     UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       16800000
# 11     UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       18900000
# 12     UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       23100000
# 13     UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       15540000
# 14     UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       11340000
# 15     UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       21000000
# 16     UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       14700000
# 17     UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       12000000
# 18     UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       20000000
# 19     UNIVERSIDAD FRANCISCO DE PAULA SANTANDER       16898000
# 20                    Universidad del Magdalena        3000000
# 21                    Universidad del Magdalena        5500000
# 22                      UNIVERSIDAD DE PAMPLONA       10000000
# 23                      UNIVERSIDAD DE PAMPLONA        6000000
# 24                      UNIVERSIDAD DE PAMPLONA        7500000
# 25                      UNIVERSIDAD DE PAMPLONA       27040000
# 26                  UNIVERSIDAD DE CUNDINAMARCA        3600000
# 27                  UNIVERSIDAD DE CUNDINAMARCA       40000000
# 28                  UNIVERSIDAD DE CUNDINAMARCA       74100000
# 29                  UNIVERSIDAD DE CUNDINAMARCA       34000000
# ...                                         ...            ...
# 39400                     ALCALDÍA DE ZIPAQUIRÁ       29744000
# 39401                     ALCALDÍA DE ZIPAQUIRÁ       16000000
# 39402                     ALCALDÍA DE ZIPAQUIRÁ       13520000
# 39403                     ALCALDÍA DE ZIPAQUIRÁ       14500000
# 39404                     ALCALDÍA DE ZIPAQUIRÁ       24063200
# 39405                     ALCALDÍA DE ZIPAQUIRÁ       10816000
# 39406                     ALCALDÍA DE ZIPAQUIRÁ       14133325
# 39407                     ALCALDÍA DE ZIPAQUIRÁ        8000000
# 39408                     ALCALDÍA DE ZIPAQUIRÁ       46927293
# 39409                     ALCALDÍA DE ZIPAQUIRÁ      124430970
# 39410                     ALCALDÍA DE ZIPAQUIRÁ     1121511367
# 39411                     ALCALDÍA DE ZIPAQUIRÁ       78421000
# 39412                     ALCALDÍA DE ZIPAQUIRÁ       11483325
# 39413                     ALCALDÍA DE ZIPAQUIRÁ       76299999
# 39414                     ALCALDÍA DE ZIPAQUIRÁ      115992894
# 39415                     ALCALDÍA DE ZIPAQUIRÁ       35697000
# 39416                     ALCALDÍA DE ZIPAQUIRÁ        5600000
# 39417                     ALCALDÍA DE ZIPAQUIRÁ       49764194
# 39418                     ALCALDÍA DE ZIPAQUIRÁ       51397461
# 39419                     ALCALDÍA DE ZIPAQUIRÁ       36340000
# 39420                     ALCALDÍA DE ZIPAQUIRÁ      130840000
# 39421                     ALCALDÍA DE ZIPAQUIRÁ       37950000
# 39422                     ALCALDÍA DE ZIPAQUIRÁ       14850000
# 39423                     ALCALDÍA DE ZIPAQUIRÁ       28600000
# 39424                     ALCALDÍA DE ZIPAQUIRÁ       23100000
# 39425                     ALCALDÍA DE ZIPAQUIRÁ       35700000
# 39426                     ALCALDÍA DE ZIPAQUIRÁ       13000000
# 39427                     ALCALDÍA DE ZIPAQUIRÁ       13000000
# 39428                     ALCALDÍA DE ZIPAQUIRÁ        9690972
# 39429                     ALCALDÍA DE ZIPAQUIRÁ       30000000
#
#        Tiempo Ejecución  Contratista Identificación  \
# 0                   127                    52410370
# 1                   120                  1032473454
# 2                   127                  1026272192
# 3                   127                    43654927
# 4                   127                  1015398583
# 5                   127                  1019070056
# 6                   127                    52428506
# 7                   127                    60361414
# 8                   127                  1020731292
# 9                   127                  1014235923
# 10                  127                    52802905
# 11                  127                  1022362662
# 12                  127                    80748291
# 13                  127                  1013630614
# 14                  127                  1020784914
# 15                  127                    28555062
# 16                  127                  1110473459
# 17                   60                    52531140
# 18                  120                    80196085
# 19                   27                   860001498
# 20                   60                  1026576561
# 21                  104                    52506924
# 22                   36                    23492170
# 23                   72                    13345885
# 24                   34                    52196518
# 25                  122                   860059596
# 26                  355                  8300319767
# 27                  256                   900925411
# 28                  335                  1032390405
# 29                  333                    37333798
# ...                 ...                         ...
# 39400               249                   900149795
# 39401               158                  1118545958
# 39402               149                    20451188
# 39403               119                  1075658571
# 39404                 3                   900497553
# 39405               149                  1075665891
# 39406               265                    80664539
# 39407               149                    35401893
# 39408               263                  8001876724
# 39409                19                   900702329
# 39410               119                   901268999
# 39411               149                   901270310
# 39412               265                  1075669692
# 39413               119                   900234677
# 39414                29                   900702329
# 39415                89                    35401752
# 39416               139                  1075874917
# 39417               209                  9001753745
# 39418                29                   901011888
# 39419                12                    52960771
# 39420               149                   900320184
# 39421               330                    17354923
# 39422               330                  1075674815
# 39423               330                    11346452
# 39424               330                  1075667854
# 39425               300                   830011072
# 39426               300                    35427286
# 39427               300                    35428899
# 39428               359                   860009174
# 39429               239                   901044653
#
#                                        Razón Social    Modalidad Selección  \
# 0                      MARIA DEL MAR REINA BARRAGAN       Régimen Especial
# 1              JOHANNA HERMILDA JEGUIZAMON GUERRERO       Régimen Especial
# 2                     JULIAN SANTIAGO PRADA GALINDO       Régimen Especial
# 3                        LUISA FERNANDA GIL GALINDO       Régimen Especial
# 4                      YONATAN FERNEY ROJAS SALGADO       Régimen Especial
# 5                     CARLOS EDUARDO MORENO CAMACHO       Régimen Especial
# 6                                DOKU RAMIREZ AKEMY       Régimen Especial
# 7                    VIVIAN JIMENA GONZALEZ SANCHEZ       Régimen Especial
# 8                      WILLIAM RICARDO SOLANO LOPEZ       Régimen Especial
# 9                    KAREN LORENA HERRERA RODRIGUEZ       Régimen Especial
# 10                        PAULA ANDREA GOMEZ ARDILA       Régimen Especial
# 11                      WALTER CAMILO MARTINEZ PAEZ       Régimen Especial
# 12                         LOPEZ LOPEZ OSCAR JAVIER       Régimen Especial
# 13                     PAOLA JANETH AREVALO GALINDO       Régimen Especial
# 14                          ANGY PAOLA SOLANO LOPEZ       Régimen Especial
# 15                             ADRIANA ARJONA LLANO       Régimen Especial
# 16                       YEISON HERNANDO ARIAS MELO       Régimen Especial
# 17               GISELLE CONSUELO CAMARGO RONCANCIO       Régimen Especial
# 18                  JULIAN DARIO JAUREGUI HERNANDEZ       Régimen Especial
# 19                        LEGISLACION ECONOMICA S,A       Régimen Especial
# 20                    JHULDER GIOVANNY PARRA PATIÑO       Régimen Especial
# 21                   VICTORIA EUGENIA CETINA MONTES       Régimen Especial
# 22                  NUBIA ESPERANZA GARZON LANCHERO       Régimen Especial
# 23                      GABRIEL ENRIQUE ROMERO PEÑA       Régimen Especial
# 24                                JENNY ARIZA RAMOS       Régimen Especial
# 25     CONGREGACION DEL ORATORIO DE SAN FELIPE NERI       Régimen Especial
# 26                              COPIERS MARKET E,U,     Invitación Directa
# 27                   DISTRIBUIDORA LA DOCE LV S,A,S     Invitación Directa
# 28                       EDGAR IVAN PAEREZ CARVAJAL     Invitación Directa
# 29                 SANDRA KARIME MARTINEZ SARMIENTO     Invitación Directa
# ...                                             ...                    ...
# 39400                         SICC DE COLOMBIA LTDA   Contratación Directa
# 39401               JULIO ANDRES FERNANDEZ CARVAJAL   Contratación Directa
# 39402                  DIANA CAROLINA CASTRO GARZON   Contratación Directa
# 39403                DIEGO FERNANDO SUAREZ OLIVARES         Mínima Cuantía
# 39404                                    FUNSDEPCOL         Mínima Cuantía
# 39405                   MANUEL ANDRES LOZANO MORENO   Contratación Directa
# 39406                   JUAN PABLO SIERRA RODRIGUEZ   Contratación Directa
# 39407                  ANGELINA BARRERA DE CARDENAS   Contratación Directa
# 39408                           SOPORTE LOGICO LTDA   Contratación Directa
# 39409  OUTSOURSOUCING SERVICIOS ESPECIALIZADOS LTDA    Selección Abreviada
# 39410                   CONSORCIO PLACA HUELLA 2019  Licitaciones Públicas
# 39411   CONSORCIO INTERVENTORIA VIAS ZIPAQUIRA 2019    Concurso de Méritos
# 39412                  CARLOS FRANCISCO CUERVO DIAZ   Contratación Directa
# 39413                          FUNDACION VOZ ANIMAL    Selección Abreviada
# 39414  OUTSOURSOUCING SERVICIOS ESPECIALIZADOS LTDA    Selección Abreviada
# 39415                     MARIA INES CORREA SALAZAR         Mínima Cuantía
# 39416                      JUAN DAVID ALDANA AVELLA   Contratación Directa
# 39417                          HOGARES SI A LA VIDA    Selección Abreviada
# 39418        COLOMBIA COSTRUCCIONES Y DISEÑOS S,A,S    Selección Abreviada
# 39419                          NATALIA ACERO SUAREZ         Mínima Cuantía
# 39420         CONSTRUCOL INGENIERIA DE OBRAS S,A,S,    Concurso de Méritos
# 39421                     FABRICIANO SANCHEZ FLOREZ   Contratación Directa
# 39422               JONATAN MAURICIO CARRILLO GOMEZ   Contratación Directa
# 39423                NESTOR ORLANDO VELANDIA PINZON   Contratación Directa
# 39424                 ANGELO SEBASTIAN BELLO CASTRO   Contratación Directa
# 39425      CONSTRUCCION ES Y GERENCIA INTTEGRAL SAS   Contratación Directa
# 39426                LUZ ANGELICA INFANTE CONTRERAS   Contratación Directa
# 39427                   ANDREA PAOLA MURCIA QUIROGA   Contratación Directa
# 39428                SEGUROS DE VIDA DEL ESTADO S,A         Mínima Cuantía
# 39429                         EXTRATEGIA MEDIOS SAS         Mínima Cuantía
#
#                                 Procedimiento Causal Fecha Contrato  Mes  \
# 0                                  Orden de Servicio     2019-01-25    1
# 1                                  Orden de Servicio     2019-01-25    1
# 2                                  Orden de Servicio     2019-01-25    1
# 3                                  Orden de Servicio     2019-01-25    1
# 4                                  Orden de Servicio     2019-01-25    1
# 5                                  Orden de Servicio     2019-01-25    1
# 6                                  Orden de Servicio     2019-01-25    1
# 7                                  Orden de Servicio     2019-01-25    1
# 8                                  Orden de Servicio     2019-01-25    1
# 9                                  Orden de Servicio     2019-01-25    1
# 10                                 Orden de Servicio     2019-01-25    1
# 11                                 Orden de Servicio     2019-01-25    1
# 12                                 Orden de Servicio     2019-01-25    1
# 13                                 Orden de Servicio     2019-01-28    1
# 14                                 Orden de Servicio     2019-01-28    1
# 15                                 Orden de Servicio     2019-01-28    1
# 16                                 Orden de Servicio     2019-01-28    1
# 17                                 Orden de Servicio     2019-01-30    1
# 18                                 Orden de Servicio     2019-01-30    1
# 19                                 Orden de Servicio     2019-01-31    1
# 20                            Manual de Contratación     2019-04-23    4
# 21                            Manual de Contratación     2019-03-20    3
# 22                            Manual de Contratación     2019-04-29    4
# 23                            Manual de Contratación     2019-01-23    1
# 24                            Manual de Contratación     2019-04-23    4
# 25         Arrendamientos y Adquisición de Inmuebles     2019-03-05    3
# 26                            Manual de Contratación     2019-05-03    5
# 27                            Manual de Contratación     2019-05-03    5
# 28                            Manual de Contratación     2019-05-06    5
# 29                            Manual de Contratación     2019-05-03    5
# ...                                              ...            ...  ...
# 39400  Prestación de Servicios Profesionales y Apoyo     2019-04-02    4
# 39401  Prestación de Servicios Profesionales y Apoyo     2019-04-02    4
# 39402  Prestación de Servicios Profesionales y Apoyo     2019-04-02    4
# 39403                      Porcentaje Mínima Cuantía     2019-04-02    4
# 39404                      Porcentaje Mínima Cuantía     2019-04-02    4
# 39405  Prestación de Servicios Profesionales y Apoyo     2019-04-23    4
# 39406  Prestación de Servicios Profesionales y Apoyo     2019-04-24    4
# 39407  Prestación de Servicios Profesionales y Apoyo     2019-04-24    4
# 39408  Prestación de Servicios Profesionales y Apoyo     2019-04-30    4
# 39409                  Contratación de Menor Cuantía     2019-04-22    4
# 39410                             LIcitación Pública     2019-04-30    4
# 39411                                        Abierto     2019-04-30    4
# 39412  Prestación de Servicios Profesionales y Apoyo     2019-04-24    4
# 39413                  Contratación de Menor Cuantía     2019-04-23    4
# 39414                  Contratación de Menor Cuantía     2019-04-30    4
# 39415                      Porcentaje Mínima Cuantía     2019-04-23    4
# 39416  Prestación de Servicios Profesionales y Apoyo     2019-04-23    4
# 39417                  Contratación de Menor Cuantía     2019-04-14    4
# 39418                  Contratación de Menor Cuantía     2019-04-29    4
# 39419                      Porcentaje Mínima Cuantía     2019-04-30    4
# 39420                                        Abierto     2019-02-05    2
# 39421  Prestación de Servicios Profesionales y Apoyo     2019-03-04    3
# 39422  Prestación de Servicios Profesionales y Apoyo     2019-03-04    3
# 39423  Prestación de Servicios Profesionales y Apoyo     2019-03-04    3
# 39424  Prestación de Servicios Profesionales y Apoyo     2019-03-04    3
# 39425  Prestación de Servicios Profesionales y Apoyo     2019-04-01    4
# 39426  Prestación de Servicios Profesionales y Apoyo     2019-04-01    4
# 39427  Prestación de Servicios Profesionales y Apoyo     2019-04-01    4
# 39428                      Porcentaje Mínima Cuantía     2019-04-30    4
# 39429                      Porcentaje Mínima Cuantía     2019-04-30    4
#
#         Año    Municipio      PROVINCIA  municipio_codigo  departamento  \
# 0      2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 1      2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 2      2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 3      2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 4      2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 5      2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 6      2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 7      2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 8      2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 9      2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 10     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 11     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 12     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 13     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 14     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 15     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 16     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 17     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 18     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 19     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 20     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 21     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 22     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 23     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 24     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 25     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 26     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 27     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 28     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# 29     2019  Bogotá D,C,         BOGOTÁ               149   Bogotá D,C,
# ...     ...          ...            ...               ...           ...
# 39400  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39401  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39402  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39403  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39404  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39405  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39406  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39407  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39408  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39409  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39410  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39411  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39412  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39413  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39414  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39415  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39416  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39417  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39418  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39419  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39420  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39421  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39422  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39423  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39424  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39425  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39426  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39427  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39428  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
# 39429  2019    Zipaquirá  SABANA CENTRO               570  Cundinamarca
#
#        departamento_codigo
# 0                        3
# 1                        3
# 2                        3
# 3                        3
# 4                        3
# 5                        3
# 6                        3
# 7                        3
# 8                        3
# 9                        3
# 10                       3
# 11                       3
# 12                       3
# 13                       3
# 14                       3
# 15                       3
# 16                       3
# 17                       3
# 18                       3
# 19                       3
# 20                       3
# 21                       3
# 22                       3
# 23                       3
# 24                       3
# 25                       3
# 26                       3
# 27                       3
# 28                       3
# 29                       3
# ...                    ...
# 39400                   11
# 39401                   11
# 39402                   11
# 39403                   11
# 39404                   11
# 39405                   11
# 39406                   11
# 39407                   11
# 39408                   11
# 39409                   11
# 39410                   11
# 39411                   11
# 39412                   11
# 39413                   11
# 39414                   11
# 39415                   11
# 39416                   11
# 39417                   11
# 39418                   11
# 39419                   11
# 39420                   11
# 39421                   11
# 39422                   11
# 39423                   11
# 39424                   11
# 39425                   11
# 39426                   11
# 39427                   11
# 39428                   11
# 39429                   11
#
# [39430 rows x 17 columns]

# %%
# Contar el número de observaciones que contiene la base: es este caso nos indica el total de contratos en Cundinamarca y Bogotá
len(base)
# Out:
# 39430

# %% [markdown]
# # Número de contratos por Municipio

# %%
# queremos determinar el # de contratos que se han firmado por municipio
contrato_mun = base.groupby('Municipio') # agrupamos la base por cada municipio
contratos = contrato_mun["Municipio"].agg('count') # generamos un contador para que cada observación dependiendo el municipio y sume el total de contratos.
contratos
# Out:
# Municipio
# Agua De Dios                  153
# Albán                          69
# Anapoima                      241
# Anolaima                      214
# Apulo                         161
# Arbeláez                      576
# Beltrán                        93
# Bituima                         6
# Bogotá D,C,                  3478
# Bojacá                        116
# Cabrera                        46
# Cachipay                       86
# Cajicá                        928
# Caparrapí                     126
# Caqueza                       582
# Carmen De Carupa              190
# Chaguaní                       97
# Chipaque                      112
# Choachí                       101
# Chocontá                      528
# Chía                         1214
# Cogua                         175
# Cota                          978
# Cucunubá                       72
# El Colegio                    205
# El Peñón                      103
# El Rosal                      202
# Facatativá                   1284
# Fomeque                       384
# Fosca                         158
#                              ...
# Sopó                          828
# Subachoque                    116
# Suesca                        216
# Supatá                         81
# Susa                           60
# Sutatausa                      78
# Tabio                         437
# Tausa                         159
# Tena                          105
# Tenjo                         488
# Tibacuy                       105
# Tibirita                       54
# Tocaima                       410
# Tocancipá                     587
# Topaipí                        60
# Ubalá                         135
# Ubaque                        116
# Une                           137
# Venecia                        62
# Vergara                       195
# Vianí                         101
# Villa De San Die De Ubate     716
# Villagómez                     92
# Villapinzón                   168
# Villeta                       760
# Viotá                         240
# Yacopí                        187
# Zipacón                       101
# Zipaquirá                     702
# Útica                         152
# Name: Municipio, Length: 117, dtype: int64

# %% [markdown]
# # Monto contratado por municipio

# %%
#queremos determinar el monton de contratación por municipio
valor_mun = base.groupby(['Municipio'])["Valor Inicial"].sum() # generamos una suma del monto de contratación por municipio.
valor_mun
# Out:
# Municipio
# Agua De Dios                   2559844501
# Albán                          1501516912
# Anapoima                      18577990069
# Anolaima                       6802222889
# Apulo                          2305530603
# Arbeláez                      14093025119
# Beltrán                        2796676650
# Bituima                          84127333
# Bogotá D,C,                  309539830325
# Bojacá                         2221753798
# Cabrera                        1182760853
# Cachipay                       2040263199
# Cajicá                        54957568457
# Caparrapí                      2663852158
# Caqueza                       15835180456
# Carmen De Carupa               7735283076
# Chaguaní                       1574353434
# Chipaque                       2550988192
# Choachí                        2737862245
# Chocontá                       9707340566
# Chía                         182445058510
# Cogua                          4466702855
# Cota                          72460722417
# Cucunubá                       1558395781
# El Colegio                     3219666644
# El Peñón                       1032896773
# El Rosal                      13470117785
# Facatativá                    51566753319
# Fomeque                        7716962278
# Fosca                          2352276674
#                                  ...
# Sopó                          38916319821
# Subachoque                     3638052619
# Suesca                         3667885849
# Supatá                         1822411017
# Susa                           1493250350
# Sutatausa                      1887500076
# Tabio                          8708297427
# Tausa                          5179028532
# Tena                           2485725519
# Tenjo                         28840708170
# Tibacuy                        2586125845
# Tibirita                       1763371036
# Tocaima                        7701206630
# Tocancipá                    116514659614
# Topaipí                         724462642
# Ubalá                          2170458545
# Ubaque                         1277729716
# Une                            2279880804
# Venecia                         940053162
# Vergara                        3655420064
# Vianí                          6023295128
# Villa De San Die De Ubate     14948953888
# Villagómez                     2836707779
# Villapinzón                    7308579315
# Villeta                       15636066246
# Viotá                          4278487201
# Yacopí                         7782069741
# Zipacón                        3497472685
# Zipaquirá                     32485352757
# Útica                          4933123193
# Name: Valor Inicial, Length: 117, dtype: int64

# %% [markdown]
# # Número de contratos por Provincias

# %%
# queremos determinar el # de contratos que se han firmado por Provincia
contratos_provincia = base.groupby('PROVINCIA') # agrupamos la base por cada Provincia
contratosP = contratos_provincia["PROVINCIA"].agg('count') # generamos un contador para que cada observación dependiendo de la provincia y sume el total de contratos por provincia.
contratosP
# Out:
# PROVINCIA
# ALMEIDAS            2109
# ALTO MAGDALENA      2345
# BAJO MAGDALENA       513
# BOGOTÁ              3478
# GUALIVA             2303
# GUAVIO              1575
# MAGDALENA CENTRO     680
# MEDINA               419
# ORIENTE             1862
# RIO NEGRO           1225
# SABANA CENTRO       5314
# SABANA OCCIDENTE    5996
# SOACHA              3151
# SUMAPAZ             4311
# TEQUENDAMA          2288
# UBATE               1861
# Name: PROVINCIA, dtype: int64

# %%
Contrac=pd.DataFrame(contratosP) # realizamos un data frame con el número de contratos de cada provincia para agragarlo como una lista en el label de nuestra gafica
num_contrac=Contrac.values.tolist()

# %% [markdown]
# # Graficar el número de contratos por provincias

# %%
 # graficamos el número de contratos por provincias con la agrupación que realizamos
gra = contratosP.plot(kind='bar' , figsize = (16,9), fontsize = 15, legend=None);
gra.set_title("Número de contratos por provincias", fontsize=30, fontname="Verdana")
# con el data frame creado anteriormente vamos a agregarlo en el label de la grafica
for i in gra.patches:
    num_contrac.append(i.get_width())

# aqui agregamos la etiqueta a cada barra de la grafica
for i in gra.patches:
    # realizamos algunos cambios como centrar las etiquetas definir negrilla y tamaño
    gra.text( i.get_x()+ i.get_width() / 2, i.get_height(), \
            str(round((i.get_height()))), fontsize=15,
                color='black',va='bottom', ha="center", fontweight='bold')
plt.savefig('contratos por provincia')

# %% [markdown]
# # Gasto total en contratación por Provincia

# %%
# queremos determinar el monton de gasto en contratación por provincia
gasto_provincia = base.groupby(['PROVINCIA'])["Valor Inicial"].sum() # generamos una suma del gasto por provincia.
gasto_provincia
# para mayor comprensión de los datos expresamos el gasto en miles de millones de pesos
gasto = (gasto_provincia/1000000000)

# %%
# Creo un Data frame con el total de gasto en contratación de cada provincia y luego lo convierto en una lista para utilizarlo como label en la gráfica.
Gasto=pd.DataFrame(gasto)
G=Gasto.values.tolist()

# %% [markdown]
# # Grafica por total de gasto en contratacion

# %%
# Graficamos el monto total de gasto en contratación correspondiente a cada provincia.
gra = gasto.plot(kind='bar' , figsize = (20,9), fontsize = 15, legend=None);
gra.set_title("Gasto total en contratación por provincia", fontsize=40, fontname="Verdana")
# con el Data frame creado anteriormente correspondiente a los montos de gasto en contratación de cada provincia, lo vamos a agregar como el label de cada barra
for i in gra.patches:
    G.append(i.get_width())

# aqui se agrega el Data frame como etiqueta de cada barra
for i in gra.patches:
    # realizamos algunos cambios como centrar las etiquetas definir negrilla y tamaño 
    gra.text( i.get_x()+ i.get_width() / 2, i.get_height(), \
           "$"  + str(round(i.get_height(),1)), fontsize=10,
                color='black',va='bottom', ha="center")
    
plt.savefig('Gasto total en contratación por provincia')

# %% [markdown]
# # Porcentaje de gasto de contratación por provincia

# %%
# Ahora queremos determinar el procentaje del monto total de contratación correspondiente a cada provincia
gasto_total = sum(gasto) # expresamos el monto total del gasto en contratación en miles de millones de pesos
gasto_total
# Out:
# 1746.221394956

# %%
# determinamos el porcentaje del monto del gasto por provincia referente al gasto total en contratación
porcentaje_provincia = (gasto/gasto_total)*100

porcentaje_provincia = round(porcentaje_provincia,1)
porcentaje_provincia
# Out:
# PROVINCIA
# ALMEIDAS             3.4
# ALTO MAGDALENA       3.6
# BAJO MAGDALENA       0.7
# BOGOTÁ              17.7
# GUALIVA              2.9
# GUAVIO               2.3
# MAGDALENA CENTRO     1.1
# MEDINA               0.4
# ORIENTE              2.7
# RIO NEGRO            2.2
# SABANA CENTRO       25.9
# SABANA OCCIDENTE    16.6
# SOACHA               6.9
# SUMAPAZ              6.7
# TEQUENDAMA           3.9
# UBATE                3.1
# Name: Valor Inicial, dtype: float64

# %% [markdown]
# # Grafica porcentaje de gasto en contratación

# %%
# realizamos la grafica del porcentaje de gasto en contratación por provincia
gra = porcentaje_provincia.plot(kind='bar' , figsize = (20,10), fontsize = 15, legend=None);
gra.set_title("Porcentaje de gasto por provincia", fontsize=40, fontname="Verdana", fontweight='bold')

for i in gra.patches: # agregamos el Data frame creado anteriormente como labels para cada barra
    G.append(i.get_width())

for i in gra.patches:
    #  realizamos algunos cambios como centrar las etiquetas definir negrilla y tamaño 
    gra.text( i.get_x()+ i.get_width() / 2, i.get_height(), \
            str(round((i.get_height()),1))+" %", fontsize=10,
                color='black',va='bottom', ha="center", fontweight='bold')
    
plt.savefig('Porcentaje de gasto por provincia')

# %% [markdown]
# # Gasto en contratación y número de contratos por modalidad de contratación

# %%
# realizamos la agregación por modalidad de contratación y conteo de contratos y lo convertimos en un Data Frame
contratos_modalidad = base.groupby(['Modalidad Selección'], axis=0)["Valor Inicial"].count()
contratos_modalidad.to_frame()
cont_moda=contratos_modalidad.reset_index(level=0)
cont_moda
# realizamos la agregación por modalidad de contratación y suma de contratos y lo convertimos en un Data Frame
contratos_modalidad2 = base.groupby(['Modalidad Selección'], axis=0)["Valor Inicial"].sum()
contratos_modalidad2.to_frame()
contratos_modalidad2 = (contratos_modalidad2/1000000000)
cont_moda2=contratos_modalidad2.reset_index(level=0)
cont_moda2
# realizamos el merge entre el número de contratos y gasto de contración
cont_mod_ = pd.merge(cont_moda, cont_moda2, how="outer", on="Modalidad Selección")
cont_mod_


cont_mod_.columns = ['Modalidad Selección','contratos', 'Valor Inicial']
cont_mod_ = cont_mod_.round(1)
cont_mod_
# Out:
#                        Modalidad Selección  contratos  Valor Inicial
# 0                      Concurso de Méritos        109           31.9
# 1                     Contratación Directa      21905          681.6
# 2  Convocatoria Pública - Decreto 092/2017         45           36.0
# 3                       Invitación Cerrada         20            4.9
# 4                       Invitación Directa       2626           49.1
# 5                       Invitación Pública         10            7.9
# 6                    Licitaciones Públicas        215          417.5
# 7                           Mínima Cuantía       2350           35.4
# 8                         Régimen Especial      11504          314.7
# 9                      Selección Abreviada        646          167.3

# %% [markdown]
# # Gasto en contratación por modalidad de contratación y número de contratos por provincia

# %%
# queremos generar un Dataframe que nos indique el número de contratos y gasto en contratación por provincia

# realizamos la agregación por ConcursodeMéritos-Modalidaddecontratación y número de contratos, y lo convertimos en un Data Frame
Concurso_meritos = base[base["Modalidad Selección"]=="Concurso de Méritos"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].count()
Concurso_meritos.to_frame()
Con_meritos=Concurso_meritos.reset_index(level=0)
Con_meritos
# realizamos la agregación de contratos y gasto en contratación y lo convertimos en un Data Frame
Concurso_meritos2 = base[base["Modalidad Selección"]=="Concurso de Méritos"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].sum()
Concurso_meritos2.to_frame()
Concurso_meritos2 = (Concurso_meritos2/1000000000)
Con_meritos2=Concurso_meritos2.reset_index(level=0)
# realizamos el merge de los contratos y la suma de gasto en contratación por provincia 
Con_meritos = pd.merge(Con_meritos, Con_meritos2, how="outer", on="PROVINCIA")
Con_meritos

# realizamos la agregación por InvitaciónDirecta-Modalidaddecontratación y número de contratos, y lo convertimos en un Data Frame
Invitación_Directa = base[base["Modalidad Selección"]=="Invitación Directa"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].count()
Invitación_Directa.to_frame()
Inv_directa=Invitación_Directa.reset_index(level=0)
Inv_directa
# realizamos la agregación de contratos y gasto en contratación y lo convertimos en un Data Frame
Invitación_Directa2 = base[base["Modalidad Selección"]=="Invitación Directa"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].sum()
Invitación_Directa2.to_frame()
Invitación_Directa2 = (Invitación_Directa2/1000000000)
Inv_directa2=Invitación_Directa2.reset_index(level=0)
# realizamos el merge de los contratos y la suma de gasto en contratación por provincia 
Inv_directa = pd.merge(Inv_directa, Inv_directa2, how="outer", on="PROVINCIA")
Inv_directa

# realizamos la agregación por ContrataciónDirecta-Modalidaddecontratación y número de contratos, y lo convertimos en un Data Frame
Contratación_Directa = base[base["Modalidad Selección"]=="Contratación Directa"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].count()
Contratación_Directa.to_frame()
Con_directa=Contratación_Directa.reset_index(level=0)
Con_directa
# realizamos la agregación de contratos y gasto en contratación y lo convertimos en un Data Frame
Contratación_Directa2 = base[base["Modalidad Selección"]=="Contratación Directa"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].sum()
Contratación_Directa2.to_frame()
Contratación_Directa2 = (Contratación_Directa2/1000000000)
Con_directa2=Contratación_Directa2.reset_index(level=0)
# realizamos el merge de los contratos y la suma de gasto en contratación por provincia 
Con_directa = pd.merge(Con_directa, Con_directa2, how="outer", on="PROVINCIA")
Con_directa

# realizamos la agregación por ConvocatoriaPública-Modalidaddecontratación y número de contratos, y lo convertimos en un Data Frame
Convocatoria_Pública = base[base["Modalidad Selección"]=="Convocatoria Pública - Decreto 092/2017"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].count()
Convocatoria_Pública.to_frame()
Con_Publica=Convocatoria_Pública.reset_index(level=0)
Con_Publica
# realizamos la agregación de contratos y gasto en contratación y lo convertimos en un Data Frame
Convocatoria_Pública2 = base[base["Modalidad Selección"]=="Convocatoria Pública - Decreto 092/2017"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].sum()
Convocatoria_Pública2.to_frame()
Convocatoria_Pública2 = (Convocatoria_Pública2/1000000000)
Con_Publica2=Convocatoria_Pública2.reset_index(level=0)
# realizamos el merge de los contratos y la suma de gasto en contratación por provincia 
Con_Publica = pd.merge(Con_Publica, Con_Publica2, how="outer", on="PROVINCIA")
Con_Publica

# realizamos la agregación por InvitaciónDirecta-Modalidaddecontratación y número de contratos, y lo convertimos en un Data Frame
Invitación_Cerrada = base[base["Modalidad Selección"]=="Invitación Cerrada"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].count()
Invitación_Cerrada.to_frame()
Inv_Cerrada=Invitación_Cerrada.reset_index(level=0)
Inv_Cerrada
# realizamos la agregación de contratos y gasto en contratación y lo convertimos en un Data Frame
Invitación_Cerrada2 = base[base["Modalidad Selección"]=="Invitación Cerrada"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].sum()
Invitación_Cerrada2.to_frame()
Invitación_Cerrada2 = (Invitación_Cerrada2/1000000000)
Inv_Cerrada2=Invitación_Cerrada2.reset_index(level=0)
# realizamos el merge de los contratos y la suma de gasto en contratación por provincia 
Inv_Cerrada = pd.merge(Inv_Cerrada, Inv_Cerrada2, how="outer", on="PROVINCIA")
Inv_Cerrada

# realizamos la agregación por InvitaciónPública-Modalidaddecontratación y número de contratos, y lo convertimos en un Data Frame
Invitación_Pública = base[base["Modalidad Selección"]=="Invitación Pública"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].count()
Invitación_Pública.to_frame()
Inv_Pública=Invitación_Pública.reset_index(level=0)
Inv_Pública
# realizamos la agregación de contratos y gasto en contratación y lo convertimos en un Data Frame
Invitación_Pública2 = base[base["Modalidad Selección"]=="Invitación Pública"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].sum()
Invitación_Pública2.to_frame()
Invitación_Pública2 = (Invitación_Pública2/1000000000)
Inv_Pública2=Invitación_Pública2.reset_index(level=0)
# realizamos el merge de los contratos y la suma de gasto en contratación por provincia 
Inv_Pública = pd.merge(Inv_Pública, Inv_Pública2, how="outer", on="PROVINCIA")
Inv_Pública

# realizamos la agregación por LicitacionesPúblicas-Modalidaddecontratación y número de contratos, y lo convertimos en un Data Frame
Licitaciones_Pública = base[base["Modalidad Selección"]=="Licitaciones Públicas"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].count()
Licitaciones_Pública.to_frame()
Lic_Pública=Licitaciones_Pública.reset_index(level=0)
Lic_Pública
# realizamos la agregación de contratos y gasto en contratación y lo convertimos en un Data Frame
Licitaciones_Pública2 = base[base["Modalidad Selección"]=="Licitaciones Públicas"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].sum()
Licitaciones_Pública2.to_frame()
Licitaciones_Pública2 = (Licitaciones_Pública2/1000000000)
Lic_Pública2=Licitaciones_Pública2.reset_index(level=0)
# realizamos el merge de los contratos y la suma de gasto en contratación por provincia 
Lic_Pública = pd.merge(Lic_Pública, Lic_Pública2, how="outer", on="PROVINCIA")
Lic_Pública

# realizamos la agregación por MínimaCuantía-Modalidaddecontratación y número de contratos, y lo convertimos en un Data Frame
Mínima_Cuantía = base[base["Modalidad Selección"]=="Mínima Cuantía"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].count()
Mínima_Cuantía.to_frame()
Mín_Cuantía=Mínima_Cuantía.reset_index(level=0)
Mín_Cuantía
# realizamos la agregación de contratos y gasto en contratación y lo convertimos en un Data Frame
Mínima_Cuantía2 = base[base["Modalidad Selección"]=="Mínima Cuantía"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].sum()
Mínima_Cuantía2.to_frame()
Mínima_Cuantía2 = (Mínima_Cuantía2/1000000000)
Mín_Cuantía2=Mínima_Cuantía2.reset_index(level=0)
# realizamos el merge de los contratos y la suma de gasto en contratación por provincia 
Mín_Cuantía = pd.merge(Mín_Cuantía, Mín_Cuantía2, how="outer", on="PROVINCIA")
Mín_Cuantía

# realizamos la agregación por RégimenEspecial-Modalidaddecontratación y número de contratos, y lo convertimos en un Data Frame
Régimen_Especial = base[base["Modalidad Selección"]=="Régimen Especial"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].count()
Régimen_Especial.to_frame()
Rég_Especial=Régimen_Especial.reset_index(level=0)
Rég_Especial
# realizamos la agregación de contratos y gasto en contratación y lo convertimos en un Data Frame
Régimen_Especial2 = base[base["Modalidad Selección"]=="Régimen Especial"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].sum()
Régimen_Especial2.to_frame()
Régimen_Especial2 = (Régimen_Especial2/1000000000)
Rég_Especial2=Régimen_Especial2.reset_index(level=0)
# realizamos el merge de los contratos y la suma de gasto en contratación por provincia 
Rég_Especial = pd.merge(Rég_Especial, Rég_Especial2, how="outer", on="PROVINCIA")
Rég_Especial

# realizamos la agregación por SelecciónAbreviada-Modalidaddecontratación y número de contratos, y lo convertimos en un Data Frame
Selección_Abreviada = base[base["Modalidad Selección"]=="Selección Abreviada"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].count()
Selección_Abreviada.to_frame()
Sel_Abreviada=Selección_Abreviada.reset_index(level=0)
Sel_Abreviada
# realizamos la agregación de contratos y gasto en contratación y lo convertimos en un Data Frame
Selección_Abreviada2 = base[base["Modalidad Selección"]=="Selección Abreviada"].groupby(['PROVINCIA'], axis=0)["Valor Inicial"].sum()
Selección_Abreviada2.to_frame()
Selección_Abreviada2 = (Selección_Abreviada2/1000000000)
Sel_Abreviada2=Selección_Abreviada2.reset_index(level=0)
# realizamos el merge de los contratos y la suma de gasto en contratación por provincia 
Sel_Abreviada = pd.merge(Sel_Abreviada, Sel_Abreviada2, how="outer", on="PROVINCIA")
Sel_Abreviada

# hacemos el merge uno a uno empezando por el gasto total en contratación y cada una de las modalidades de contratación
por_modalidad= pd.merge(Con_meritos, Inv_directa, how='outer',  on='PROVINCIA')
por_modalidad= pd.merge(por_modalidad,Con_directa,how='outer',  on='PROVINCIA')
por_modalidad= pd.merge(por_modalidad,Con_Publica,how='outer',  on='PROVINCIA')
por_modalidad= pd.merge(por_modalidad,Inv_Cerrada,how='outer',  on='PROVINCIA')
por_modalidad= pd.merge(por_modalidad,Inv_Pública,how='outer',  on='PROVINCIA')
por_modalidad= pd.merge(por_modalidad,Lic_Pública,how='outer',  on='PROVINCIA')
por_modalidad= pd.merge(por_modalidad,Mín_Cuantía,how='outer',  on='PROVINCIA')
por_modalidad= pd.merge(por_modalidad,Rég_Especial,how='outer',  on='PROVINCIA')
por_modalidad= pd.merge(por_modalidad,Sel_Abreviada,how='outer',  on='PROVINCIA')
por_modalidad

# vamos a renombrar las columnas para identificar la inversión por convenio
por_modalidad.columns = ['PROVINCIA','Concurso de Méritos', 'Con_meritos','Invitación Directa', 'Inv_directa','Contratación Directa', 'Con_directa','Convocatoria Pública - Decreto 092/2017', 'Con_Publica','Invitación Cerrada', 'Inv_Cerrada', 'Invitación Pública', 'Inv_Pública', 'Licitaciones Públicas', 'Lic_Pública', 'Mínima Cuantía', 'Mín_Cuantía', 'Régimen Especial', 'Rég_Especial', 'Selección Abreviada', 'Sel_Abreviada']

# los valores que tienen NaN se convierten a 0
por_modalidad.fillna(0, inplace=True)

# Redondear los valores a un solo decimal
por_modalidad=por_modalidad.round(1)
por_modalidad
# Out:
#            PROVINCIA  Concurso de Méritos  Con_meritos  Invitación Directa  \
# 0           ALMEIDAS                 15.0          2.6                 2.0
# 1     ALTO MAGDALENA                  7.0          0.6               266.0
# 2             BOGOTÁ                  4.0          2.3                23.0
# 3            GUALIVA                  5.0          0.3                 0.0
# 4             GUAVIO                  5.0          0.6                 1.0
# 5   MAGDALENA CENTRO                  4.0          0.3                 4.0
# 6             MEDINA                  1.0          0.1                 0.0
# 7            ORIENTE                  3.0          0.4                68.0
# 8          RIO NEGRO                  3.0          0.1                55.0
# 9      SABANA CENTRO                 32.0         17.4               378.0
# 10  SABANA OCCIDENTE                  8.0          4.1               251.0
# 11            SOACHA                  8.0          1.7               136.0
# 12           SUMAPAZ                  1.0          0.1               763.0
# 13        TEQUENDAMA                  9.0          1.1               513.0
# 14             UBATE                  4.0          0.2               142.0
# 15    BAJO MAGDALENA                  0.0          0.0                24.0
#
#     Inv_directa  Contratación Directa  Con_directa  \
# 0           0.1                   957         19.4
# 1           4.2                  1453         25.9
# 2           0.6                  2786        169.6
# 3           0.0                  1257         23.7
# 4           0.0                   988         20.4
# 5           0.1                   391          6.0
# 6           0.0                   156          2.4
# 7           0.5                  1063         22.8
# 8           0.7                   553         14.8
# 9           8.0                  3531        100.5
# 10          7.1                  3622        121.7
# 11          1.9                  1701         60.3
# 12         12.1                  1481         40.8
# 13         11.6                   968         20.4
# 14          2.1                   819         26.9
# 15          0.3                   179          6.0
#
#     Convocatoria Pública - Decreto 092/2017  Con_Publica  Invitación Cerrada  \
# 0                                       1.0          0.1                 0.0
# 1                                       4.0          2.5                 1.0
# 2                                       7.0         25.6                 1.0
# 3                                       3.0          0.6                 0.0
# 4                                       3.0          0.3                 0.0
# 5                                       1.0          0.3                 0.0
# 6                                       0.0          0.0                 0.0
# 7                                       0.0          0.0                 0.0
# 8                                       2.0          0.1                 0.0
# 9                                      15.0          4.0                 5.0
# 10                                      0.0          0.0                 4.0
# 11                                      0.0          0.0                 0.0
# 12                                      0.0          0.0                 1.0
# 13                                      4.0          1.9                 0.0
# 14                                      5.0          0.7                 8.0
# 15                                      0.0          0.0                 0.0
#
#         ...        Invitación Pública  Inv_Pública  Licitaciones Públicas  \
# 0       ...                       0.0          0.0                      9
# 1       ...                       1.0          0.5                     14
# 2       ...                       0.0          0.0                      5
# 3       ...                       0.0          0.0                     12
# 4       ...                       0.0          0.0                      7
# 5       ...                       2.0          0.0                      9
# 6       ...                       0.0          0.0                      1
# 7       ...                       0.0          0.0                     13
# 8       ...                       0.0          0.0                     16
# 9       ...                       0.0          0.0                     45
# 10      ...                       1.0          0.0                     28
# 11      ...                       0.0          0.0                     18
# 12      ...                       4.0          6.1                      5
# 13      ...                       2.0          1.3                     18
# 14      ...                       0.0          0.0                     12
# 15      ...                       0.0          0.0                      3
#
#     Lic_Pública  Mínima Cuantía  Mín_Cuantía  Régimen Especial  Rég_Especial  \
# 0          13.6             134          2.0               931          13.3
# 1          14.7             195          3.2               362           3.9
# 2          18.5              62          1.3               556          78.9
# 3          10.4             217          2.9               754           7.9
# 4           3.3             117          1.7               413           8.9
# 5           7.4              71          1.0               173           1.7
# 6           0.5              40          0.7               212           2.6
# 7           3.5             208          2.7               472          12.7
# 8           8.1              88          1.0               483          10.5
# 9         201.4             211          4.7              1037          38.2
# 10         84.8             192          3.1              1815          55.2
# 11         21.5             186          3.1              1060          24.3
# 12          6.2             241          3.1              1768          37.0
# 13         15.9             198          2.6               521           7.2
# 14          6.9             149          2.0               686           8.7
# 15          0.9              41          0.6               261           3.8
#
#     Selección Abreviada  Sel_Abreviada
# 0                    60            7.7
# 1                    42            7.8
# 2                    34           12.7
# 3                    55            5.7
# 4                    41            5.4
# 5                    25            2.7
# 6                     9            0.8
# 7                    35            3.8
# 8                    25            2.8
# 9                    60           76.3
# 10                   75           11.7
# 11                   42            7.2
# 12                   47           11.3
# 13                   55            6.2
# 14                   36            4.7
# 15                    5            0.6
#
# [16 rows x 21 columns]

# %%
# Cuadro con la distribución de los montos de la contratación segun la modalidad de contratación por cada una de las privincias
in_modalidad = por_modalidad.drop(columns=['Concurso de Méritos','Invitación Directa','Contratación Directa','Convocatoria Pública - Decreto 092/2017', 'Invitación Cerrada', 'Invitación Pública', 'Licitaciones Públicas', 'Mínima Cuantía', 'Régimen Especial', 'Selección Abreviada'])
in_modalidad
# Out:
#            PROVINCIA  Con_meritos  Inv_directa  Con_directa  Con_Publica  \
# 0           ALMEIDAS          2.6          0.1         19.4          0.1
# 1     ALTO MAGDALENA          0.6          4.2         25.9          2.5
# 2             BOGOTÁ          2.3          0.6        169.6         25.6
# 3            GUALIVA          0.3          0.0         23.7          0.6
# 4             GUAVIO          0.6          0.0         20.4          0.3
# 5   MAGDALENA CENTRO          0.3          0.1          6.0          0.3
# 6             MEDINA          0.1          0.0          2.4          0.0
# 7            ORIENTE          0.4          0.5         22.8          0.0
# 8          RIO NEGRO          0.1          0.7         14.8          0.1
# 9      SABANA CENTRO         17.4          8.0        100.5          4.0
# 10  SABANA OCCIDENTE          4.1          7.1        121.7          0.0
# 11            SOACHA          1.7          1.9         60.3          0.0
# 12           SUMAPAZ          0.1         12.1         40.8          0.0
# 13        TEQUENDAMA          1.1         11.6         20.4          1.9
# 14             UBATE          0.2          2.1         26.9          0.7
# 15    BAJO MAGDALENA          0.0          0.3          6.0          0.0
#
#     Inv_Cerrada  Inv_Pública  Lic_Pública  Mín_Cuantía  Rég_Especial  \
# 0           0.0          0.0         13.6          2.0          13.3
# 1           0.0          0.5         14.7          3.2           3.9
# 2           0.0          0.0         18.5          1.3          78.9
# 3           0.0          0.0         10.4          2.9           7.9
# 4           0.0          0.0          3.3          1.7           8.9
# 5           0.0          0.0          7.4          1.0           1.7
# 6           0.0          0.0          0.5          0.7           2.6
# 7           0.0          0.0          3.5          2.7          12.7
# 8           0.0          0.0          8.1          1.0          10.5
# 9           1.4          0.0        201.4          4.7          38.2
# 10          1.7          0.0         84.8          3.1          55.2
# 11          0.0          0.0         21.5          3.1          24.3
# 12          0.0          6.1          6.2          3.1          37.0
# 13          0.0          1.3         15.9          2.6           7.2
# 14          1.7          0.0          6.9          2.0           8.7
# 15          0.0          0.0          0.9          0.6           3.8
#
#     Sel_Abreviada
# 0             7.7
# 1             7.8
# 2            12.7
# 3             5.7
# 4             5.4
# 5             2.7
# 6             0.8
# 7             3.8
# 8             2.8
# 9            76.3
# 10           11.7
# 11            7.2
# 12           11.3
# 13            6.2
# 14            4.7
# 15            0.6

# %%
# vamos a realizar el data frame con solo el número de contratos por modalidad de contratación
pro_modalidad = por_modalidad.drop(columns=['Con_meritos','Inv_directa','Con_directa', 'Con_Publica', 'Inv_Cerrada','Inv_Pública', 'Lic_Pública', 'Mín_Cuantía', 'Rég_Especial', 'Sel_Abreviada'])
pro_modalidad
# Out:
#            PROVINCIA  Concurso de Méritos  Invitación Directa  \
# 0           ALMEIDAS                 15.0                 2.0
# 1     ALTO MAGDALENA                  7.0               266.0
# 2             BOGOTÁ                  4.0                23.0
# 3            GUALIVA                  5.0                 0.0
# 4             GUAVIO                  5.0                 1.0
# 5   MAGDALENA CENTRO                  4.0                 4.0
# 6             MEDINA                  1.0                 0.0
# 7            ORIENTE                  3.0                68.0
# 8          RIO NEGRO                  3.0                55.0
# 9      SABANA CENTRO                 32.0               378.0
# 10  SABANA OCCIDENTE                  8.0               251.0
# 11            SOACHA                  8.0               136.0
# 12           SUMAPAZ                  1.0               763.0
# 13        TEQUENDAMA                  9.0               513.0
# 14             UBATE                  4.0               142.0
# 15    BAJO MAGDALENA                  0.0                24.0
#
#     Contratación Directa  Convocatoria Pública - Decreto 092/2017  \
# 0                    957                                      1.0
# 1                   1453                                      4.0
# 2                   2786                                      7.0
# 3                   1257                                      3.0
# 4                    988                                      3.0
# 5                    391                                      1.0
# 6                    156                                      0.0
# 7                   1063                                      0.0
# 8                    553                                      2.0
# 9                   3531                                     15.0
# 10                  3622                                      0.0
# 11                  1701                                      0.0
# 12                  1481                                      0.0
# 13                   968                                      4.0
# 14                   819                                      5.0
# 15                   179                                      0.0
#
#     Invitación Cerrada  Invitación Pública  Licitaciones Públicas  \
# 0                  0.0                 0.0                      9
# 1                  1.0                 1.0                     14
# 2                  1.0                 0.0                      5
# 3                  0.0                 0.0                     12
# 4                  0.0                 0.0                      7
# 5                  0.0                 2.0                      9
# 6                  0.0                 0.0                      1
# 7                  0.0                 0.0                     13
# 8                  0.0                 0.0                     16
# 9                  5.0                 0.0                     45
# 10                 4.0                 1.0                     28
# 11                 0.0                 0.0                     18
# 12                 1.0                 4.0                      5
# 13                 0.0                 2.0                     18
# 14                 8.0                 0.0                     12
# 15                 0.0                 0.0                      3
#
#     Mínima Cuantía  Régimen Especial  Selección Abreviada
# 0              134               931                   60
# 1              195               362                   42
# 2               62               556                   34
# 3              217               754                   55
# 4              117               413                   41
# 5               71               173                   25
# 6               40               212                    9
# 7              208               472                   35
# 8               88               483                   25
# 9              211              1037                   60
# 10             192              1815                   75
# 11             186              1060                   42
# 12             241              1768                   47
# 13             198               521                   55
# 14             149               686                   36
# 15              41               261                    5

# %%
# graficar # de proyectos por vigencia de cada departamento
ay = pro_modalidad.plot.bar(stacked=True, figsize=(26,13), fontsize = 20)

ay.set_title("Número de contratos por modalidad de contratación", fontsize=40, fontname="Verdana")

ay.set_xticklabels(pro_modalidad["PROVINCIA"])

ay.legend(fontsize=20);

plt.savefig('Número de contratos por modalidad de contratación - PROVINCIA')

# %%
# graficas del gasto en contratación por modalidad de contratación de cada provincia
ay = in_modalidad.plot.bar(stacked=True, figsize=(26,13), fontsize = 20)

ay.set_title("Gasto en Contratación por modalidad de contratación", fontsize=40, fontname="Verdana")

ay.set_xticklabels(in_modalidad["PROVINCIA"])

ay.legend(fontsize=20);

plt.savefig('Gasto en contratación por modalidad de contratación - Provincia')
